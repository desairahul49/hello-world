# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('S:\\work\\Automation\\e-Support\\analysis\\driver.xlsx')

# %%
data = data.melt(id_vars=['svc_tag_id','7k tags','Click_Bucket'],
                  value_vars=['supp_driver_id_1','supp_driver_id_2','supp_driver_id_3','supp_driver_id_4','supp_driver_id_5',
                             'supp_driver_id_6','supp_driver_id_7','supp_driver_id_8','supp_driver_id_9','supp_driver_id_10']).dropna()

# %%
data.loc[data2['svc_tag_id']=='1r3xcp2']
# Out:
#       svc_tag_id  7k tags Click_Bucket          variable  value
# 40       1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  2mgx1
# 41       1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  h41nr
# 42       1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  jd7fd
# 43       1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  rcgj3
# 44       1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  rxxvh
# 146      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  fhgpf
# 147      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  h41nr
# 148      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  xygjn
# 149      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  yfyy8
# 273      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  33r77
# 397      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  c3jkt
# 398      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  cm5fp
# 504      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  00mv7
# 505      1r3xcp2  1R3XCP2   51 & Above  supp_driver_id_1  rxdjm
# ...

# %%
excel = pd.ExcelWriter('S:\\work\\Automation\\e-Support\\analysis\\driversmelt.xlsx')
data.to_excel(excel,index = False)
excel.save()
